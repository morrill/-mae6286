# %% [markdown]
# ### Stretch of road with a stoplight

# %%
# %matplotlib inline
import numpy
from matplotlib import pyplot
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16

# %%
# Functions:

def rho_green_light(nx, rho_light):
    """Computes "green light" initial condition with shock, and linear distribution behind

    Parameters
    ----------
    nx        : int
        Number of grid points in x
    rho_light : float
        Density of cars at stoplight

    Returns
    -------
    rho: array of floats
        Array with initial values of density
    """    
    rho = numpy.arange(nx)*2./nx*rho_light # Before stoplight
    rho[int((nx-1)/2):] = 0
    return rho

def computeF(u_max, rho_max, rho):
    """Computes flux F=V*rho

    Parameters
    ----------
    u_max  : float
        Maximum allowed velocity
    rho    : array of floats
        Array with density of cars at every point x
    rho_max: float
        Maximum allowed car density
        
    Returns
    -------
    F : array
        Array with flux at every point x
    """
    return u_max*rho*(1-rho/rho_max)

def ftbs(rho, nt, dt, dx, rho_max, u_max):
    """ Computes the solution with forward in time, backward in space
    
    Parameters
    ----------
    rho    : array of floats
            Density at current time-step
    nt     : int
            Number of time steps
    dt     : float
            Time-step size
    dx     : float
            Mesh spacing
    rho_max: float
            Maximum allowed car density
    u_max  : float
            Speed limit
    
    Returns
    -------
    rho_n : array of floats
            Density after nt time steps at every point x
    """
    # initialize our results array with dimensions nt by nx
    rho_n = numpy.zeros((nt,len(rho)))
    # copy the initial u array into each row of our new array
    rho_n[0,:] = rho.copy()
    
    for t in range(1,nt):
        F = computeF(u_max, rho_max, rho)
        rho_n[t,1:] = rho[1:] - dt/dx*(F[1:] - F[:-1])
        rho_n[t,0] = rho[0]
        rho = rho_n[t].copy()
        
    return rho_n

def ftfs(rho, nt, dt, dx, rho_max, u_max):
    """ Computes the solution with forward in time, forward in space
    
    Parameters
    ----------
    rho    : array of floats
            Density at current time-step
    nt     : int
            Number of time steps
    dt     : float
            Time-step size
    dx     : float
            Mesh spacing
    rho_max: float
            Maximum allowed car density
    u_max  : float
            Speed limit
    
    Returns
    -------
    rho_n : array of floats
            Density after nt time steps at every point x
    """
    # initialize our results array with dimensions nt by nx
    rho_n = numpy.zeros((nt,len(rho)))
    # copy the initial u array into each row of our new array
    rho_n[0,:] = rho.copy()
    
    for t in range(1,nt):
        F = computeF(u_max, rho_max, rho)
        rho_n[t,:-1] = rho[:-1] - dt/dx*(F[1:] - F[:-1])
        rho_n[t,-1] = rho[-1]
        rho = rho_n[t].copy()
        
    return rho_n

"""def my_green_light(nx, x, rho_light, rho_max):
    rho = x*rho_light/2+rho_max/2
    rho[int((nx-1)/2):] = rho_max/2
    return rho"""
# Out:
# 'def my_green_light(nx, x, rho_light, rho_max):\n    rho = x*rho_light/2+rho_max/2\n    rho[int((nx-1)/2):] = rho_max/2\n    return rho'

# %%
# Initial condition paramters
# defining grid size and time steps

nx = 81
nt = 30
dx = 4.0/(nx-1)

x = numpy.linspace(0,4,nx)

rho_max = 10.
u_max = 1.
rho_light = 10.

rho = rho_green_light(nx, rho_light)

# %%
pyplot.plot(x, rho, color='#003366', ls='-', lw=3)
pyplot.ylabel('Traffic density')
pyplot.xlabel('Distance')
pyplot.ylim(-0.5, 11.);

# %%
# calculate solution:
sigma = 1.
dt = sigma*dx

rho_n = ftbs(rho, nt, dt, dx, rho_max, u_max)

# %%
# animate solution:
from matplotlib import animation
from IPython.display import HTML

# %%
fig = pyplot.figure();
ax = pyplot.axes(xlim=(0,4),ylim=(-0.5,11.5),xlabel=('Distance'),ylabel=('Traffic density'));
line, = ax.plot([],[],color='#003366', lw=2);

def animate(data):
    x = numpy.linspace(0,4,nx)
    y = data
    line.set_data(x,y)
    return line,

anim = animation.FuncAnimation(fig, animate, frames=rho_n, interval=50)

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="432.0" height="288.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### Trying initial conditions that wont blow up:

# %%
rho_light = 5.
nt = 40
rho = rho_green_light(nx, rho_light)
rho_n = ftbs(rho, nt, dt, dx, rho_max, u_max)

anim = animation.FuncAnimation(fig, animate, frames=rho_n, interval=50)
HTML(anim.to_html5_video())
# Out:
# <video width="432.0" height="288.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### Trying forward in time, forward in space
#
# I am not understanding how to do this. To be stable for a forward space scheme, you need to have the wavespeed be negative for all x. This requires all rho to be greater than half of rho_max. I also don't know if the function for ftfs is right. the scheme looks almost identical to ftbs I don't know how to make it happen with array ops.

# %%
nt = 40
u_max = -1.
rho = rho_green_light(nx, rho_light)
rho_n = ftfs(rho, nt, dt, dx, rho_max, u_max)

anim = animation.FuncAnimation(fig, animate, frames=rho_n, interval=50)
HTML(anim.to_html5_video())
# Out:
# <video width="432.0" height="288.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# I guess this is correct. All I did was make the maximum velocity negative. But I don't see how its the same problem traffic is now moving away from the traffic light. I could reverse the initial condition also but I think thats silly. Now it looks like a traffic jam happened then at some point everyone decided to turn around and drive to the left instead.

# %% [markdown]
# ### CFL business
# Basically increasing the wave speed slightly without modifying the ratio dt/dx gives a slightly large CFL # and our solution blows up.

# %%
rho_light = 4.
u_max = 1.1
nt = 40
rho = rho_green_light(nx, rho_light)
rho_n = ftbs(rho, nt, dt, dx, rho_max, u_max)

anim = animation.FuncAnimation(fig, animate, frames=rho_n, interval=50)
HTML(anim.to_html5_video())
# Out:
# <video width="432.0" height="288.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
